# %%
# Importing the libraries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
from sklearn.cluster import KMeans

# %%
# Loading the iris dataset
df=pd.read_csv('iris.csv')
print(df.head(5))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
y=df["Id"]

# %%
print("dimensions of iris: {}".format(df.shape))
# Out:
# dimensions of iris: (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.plot(x='Id', y='SepalLengthCm', style='g')  
plt.xlabel('Id')  
plt.ylabel('SepalLengthCm')  
plt.show()

# %%
df.plot(x='Id', y='SepalWidthCm', style='g')  
plt.xlabel('Id')  
plt.ylabel('SepalWidthCm')  
plt.show()

# %%
df.plot(x='Id', y='PetalLengthCm', style='g')  
plt.xlabel('Id')  
plt.ylabel('PetalLengthCm')  
plt.show()

# %%
df.plot(x='Id', y='PetalWidthCm', style='g')  
plt.xlabel('Id')  
plt.ylabel('PetalWidthCm')  
plt.show()

# %%
x =df.iloc[:, [0, 1, 2, 3]].values

# %%
# Finding the optimum number of clusters for k-means classification
lst = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    lst.append(kmeans.inertia_)

# %%
# Plotting the results onto a line graph, 
plt.plot(range(1, 11), lst)
plt.xlabel('Number of clusters')
plt.ylabel(' Within cluster sum of squares') 
plt.show()

# %% [raw]
# # Applying kmeans to the dataset / Creating the kmeans classifier
# kmeans = KMeans(n_clusters = 3, init = 'k-means++',
#                 max_iter = 300, n_init = 10, random_state = 0)
# y_pred= kmeans.fit_predict(x)
# y_pred

# %%
# Visualising the clusters - On the first two columns
plt.plot(x[y_pred == 0, 0], x[y_pred == 0, 1],c = 'blue', label = 'Iris-setosa')
plt.plot(x[y_pred == 1, 0], x[y_pred== 1, 1],c = 'yellow', label = 'Iris-versicolour')
plt.plot(x[y_pred == 2, 0], x[y_pred == 2, 1],c = 'green', label = 'Iris-virginica')
# Plotting the centroids of the clusters
plt.plot(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], c = 'red', label = 'Centroids')
